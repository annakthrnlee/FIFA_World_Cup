# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# Create database connection string
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fifa_world_cup"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Test connection to database
# dataframe name = pd.read_sql_query('select * from "table_name"',con=engine)
df = pd.read_sql_query('select * from "matches"',con=engine)

# %%
df.head()
# Out:
#    index match_date home_team     away_team home_team_continent  \
# 0      0     8/8/93   Bolivia       Uruguay       South America
# 1      1     8/8/93    Brazil        Mexico       South America
# 2      2     8/8/93   Ecuador     Venezuela       South America
# 3      3     8/8/93    Guinea  Sierra Leone              Africa
# 4      4     8/8/93  Paraguay     Argentina       South America
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0       South America                   59                   22
# 1       North America                    8                   14
# 2       South America                   35                   94
# 3              Africa                   65                   86
# 4       South America                   67                    5
#
#    home_team_total_fifa_points  away_team_total_fifa_points  ...  shoot_out  \
# 0                            0                            0  ...         No
# 1                            0                            0  ...         No
# 2                            0                            0  ...         No
# 3                            0                            0  ...         No
# 4                            0                            0  ...         No
#
#    home_team_result home_team_goalkeeper_score away_team_goalkeeper_score  \
# 0               Win                        NaN                        NaN
# 1              Draw                        NaN                        NaN
# 2               Win                        NaN                        NaN
# 3               Win                        NaN                        NaN
# 4              Lose                        NaN                        NaN
#
#   home_team_mean_defense_score  home_team_mean_offense_score  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   home_team_mean_midfield_score away_team_mean_defense_score  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    away_team_mean_offense_score  away_team_mean_midfield_score
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
# [5 rows x 26 columns]
