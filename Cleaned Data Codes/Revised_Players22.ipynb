# %%
# GOAL FOR THIS CODE: 
# This code is to clean the dataset (Players_22.csv) : delete null values, keep only the columns necessary 
# Delete any plyers who aren't ranked in the international game

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import and read International_matches.csv
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df4ce41f-3caf-4413-88b2-92217fd38f30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df4ce41f-3caf-4413-88b2-92217fd38f30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#  Import and read the dataset
import pandas as pd 
Revised_df = pd.read_csv("players_22.csv")
Revised_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
# Check the datatypes of your columns
Revised_df.dtypes
# Out:
# sofifa_id                    int64
# player_url                  object
# short_name                  object
# long_name                   object
# player_positions            object
#                             ...
# goalkeeping_handling         int64
# goalkeeping_kicking          int64
# goalkeeping_positioning      int64
# goalkeeping_reflexes         int64
# goalkeeping_speed          float64
# Length: 77, dtype: object

# %%
Revised_df.drop(["player_url", "club_team_id", "club_name", "club_jersey_number"], axis=1, inplace=True)

# %%
Revised_df.drop(["club_loaned_from", "club_joined", "club_contract_valid_until", "player_positions", "overall"], axis=1, inplace=True)

# %%
Revised_df.drop(["nation_position", "nation_jersey_number", "weak_foot", "skill_moves", "international_reputation", "work_rate"], axis=1, inplace=True)

# %%
Revised_df.drop(["release_clause_eur", "player_tags", "pace", "shooting", "pass", "dribbling", "defending", "physic", "attacking_crossing"], axis=1, inplace=True)

# %%
Revised_df.drop(["attacking_finishing", "attacking_heading_accuracy", "attacking_short_passing", "attacking_volleys", "skill_dribbling", "skill_curve"], axis=1, inplace=True)

# %%
Revised_df.drop(["skill_fk_accuracy", "skill_long_passing", "skill_ball_control", "movement_acceleration", "movement_sprint_speed", "movement_agility", "movement_reactions"], axis=1, inplace=True)

# %%
Revised_df.drop(["movement_balance", "power_shot_power", "power_jumping", "power_stamina", "power_strength", "power_long_shots", "mentality_aggression", "mentality_interceptions", "mentality_positioning", "mentality_vision"], axis=1, inplace=True)

# %%
Revised_df.drop(["mentality_penalties", "mentality_composure", "potential", "value_eur", "wage_eur", "defending_marking_awareness", "defending_standing_tackle", "defending_sliding_tackle"], axis=1, inplace=True)

# %%
Revised_df.drop(["goalkeeping_diving", "goalkeeping_handling", "goalkeeping_kicking", "goalkeeping_positioning", "goalkeeping_reflexes", "goalkeeping_speed", "club_position", "nationality_id", "league_name", "league_level"], axis=1, inplace=True)

# %%
Revised_df
# Out:
#        sofifa_id          short_name                            long_name  \
# 0         158023            L. Messi       Lionel Andrés Messi Cuccittini
# 1         188545      R. Lewandowski                   Robert Lewandowski
# 2          20801   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3         190871           Neymar Jr        Neymar da Silva Santos Júnior
# 4         192985        K. De Bruyne                      Kevin De Bruyne
# ...          ...                 ...                                  ...
# 19234     261962           Song Defu                                  宋德福
# 19235     262040           C. Porter                      Caoimhin Porter
# 19236     262760            N. Logue              Nathan Logue-Cunningham
# 19237     262820           L. Rudden                          Luke Rudden
# 19238     264540  E. Lalchhanchhuaha              Emanuel Lalchhanchhuaha
#
#        age      dob  height_cm  weight_kg     nationality_name  \
# ...

# %%
# Yes, lots and lots and lots of columns had to be dropped. Our goal is to compare highest ranked teams 2022 with players 2022 age, height, weight, body_type, and nationality

# %%
# Drop all players who don't play in the necessary leagues to match our international_matches dataframe 
nan_value = float("NaN")
Revised_df.replace("", nan_value, inplace=True)
Revised_df.dropna(subset = ["nation_team_id"], inplace=True)
Revised_df
# Out:
#        sofifa_id         short_name                            long_name  age  \
# 0         158023           L. Messi       Lionel Andrés Messi Cuccittini   34
# 1         188545     R. Lewandowski                   Robert Lewandowski   32
# 2          20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   36
# 4         192985       K. De Bruyne                      Kevin De Bruyne   30
# 6         231747          K. Mbappé                 Kylian Mbappé Lottin   22
# ...          ...                ...                                  ...  ...
# 14199     259680        M. Stamenic        Marko Seufatu Nikola Stamenic   19
# 14466     213094            S. Roux                           Storm Roux   28
# 14476     219392           A. Rufer                    Alex Arthur Rufer   25
# 14654     241475           P. Soiri              Pyry Henri Hidipo Soiri   26
# 14860     254513        C. Eriksson     Carljohan Daniel Viktor Eriksson   26
#
# ...

# %%
# Save as a new csv file
filename = 'Revised_players22.csv'

Revised_df.to_csv('/content/drive' + 'Revised_players22.csv')

# %%
from google.colab import drive

drive.mount('/content/drive')
path = '/content/drive/My Drive/Revised_Players22.csv'

with open(path, 'w', encoding = 'utf-8-sig') as f:
  Revised_df.to_csv(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
