# %% [markdown]
# <a href="https://colab.research.google.com/github/annakthrnlee/FIFA_World_Cup/blob/lee1/Supervised_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BESS: Import data from Postgres using SQLAlchemy

# %%
# Import Password for Database & dependencies
from config import db_password
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create database connection string
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fifa_world_cup"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Test connection to database
# dataframe name = pd.read_sql_query('select * from "table_name"',con=engine)
df = pd.read_sql_query('select * from "combined_table"',con=engine)

# %%
df.head()
# Out:
#    index        date home_team away_team home_team_continent  \
# 0      1  1993-08-08    Brazil    Mexico       South America
# 1      1  1993-08-08    Brazil    Mexico       South America
# 2      1  1993-08-08    Brazil    Mexico       South America
# 3      1  1993-08-08    Brazil    Mexico       South America
# 4      1  1993-08-08    Brazil    Mexico       South America
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank tournament  \
# 0       North America                    8                   14   Friendly
# 1       North America                    8                   14   Friendly
# 2       North America                    8                   14   Friendly
# 3       North America                    8                   14   Friendly
# 4       North America                    8                   14   Friendly
#
#   country  ...                     long_name  age      dob height_cm  \
# 0  Brazil  ...   Nuno Ailton Padrenda Mendes   25  2/29/96       180
# ...

# %%
# rename index column
df = df.rename(columns={'index':'match_number'})
df.head()
# Out:
#    match_number        date home_team away_team home_team_continent  \
# 0             1  1993-08-08    Brazil    Mexico       South America
# 1             1  1993-08-08    Brazil    Mexico       South America
# 2             1  1993-08-08    Brazil    Mexico       South America
# 3             1  1993-08-08    Brazil    Mexico       South America
# 4             1  1993-08-08    Brazil    Mexico       South America
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank tournament  \
# 0       North America                    8                   14   Friendly
# 1       North America                    8                   14   Friendly
# 2       North America                    8                   14   Friendly
# 3       North America                    8                   14   Friendly
# 4       North America                    8                   14   Friendly
#
#   country  ...                     long_name  age      dob height_cm  \
# ...

# %%
df.to_csv("Cleaned Data Sources/cleaned_combined_table.csv", index=False)
